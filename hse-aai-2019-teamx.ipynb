# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/32/Hochschule-esslingen.svg/320px-Hochschule-esslingen.svg.png" />
#
# <br>Name/s: Your Name, Your MartNr
# <br>Team Nr:
# <br>Team Name:
# <br>Studiengang: z.B. SWB
# <br>E-mail/s: disait00@hs-esslingen.de
#
# <br>Lecture: Applied Artificial Intelligence
# <br>Semseter: SS2019
# <br>Lecturers: Dionysios Satikidis (dionysios.satikidis@gmail.com); Jan Seyler (jan.seyler@gmail.com)
#
#
# ***

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read

# %%
# import data
df = pd.read_csv('data_getting_started.csv', sep=';', skiprows = 2)

# remove units information
df = df.drop(df.index[0])
df.index = df.index - 1

# make the seperation character '.'
df = df.apply(lambda x: x.str.replace(',','.'))

# convert data to float
df = df.astype(float)

# view data
print(df.head(5))

# plot data
df.plot()
# Out:
#      0      19,38         0.1  6,46  6,46.1  6,46.2  6,46.3         0.2  \
# 0  0.2  19.380000    0.000000  6.46    6.46    6.46    6.46    0.000000
# 1  0.3  19.380000    0.000000  6.46    6.46    6.46    6.46    0.000000
# 2  0.4  19.380000    0.000000  6.46    6.46    6.46    6.46    0.000000
# 3  0.5  19.341272  547.131573  3.23    3.23    3.23    3.23    0.079749
# 4  0.6  18.800635  745.709357  3.23    3.23    3.23    3.23  200.584906
#
#           0.3
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.127682
# 4  105.916610

# %%
## Algorithmus

# %% [markdown]
# # Clear and prepare data

# %% [markdown]
# # Algorithm / Network

# %% [markdown]
# ## Write
